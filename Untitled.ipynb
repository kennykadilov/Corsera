# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
tesla = yf.Ticker("TSLA")
tesla_data = tesla.history(period="max")

# %%
tesla_data.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
with open('untitled.html', 'r', encoding='utf-8') as file:
    # Read the HTML content
    html_content = file.read()

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Create an empty list to store DataFrames
data_frames = []

# Loop through table rows and extract data
for row in soup.find("tbody").find_all('tr'):
    col = row.find_all("td")
    date = col[0].text
    Open = col[1].text
    high = col[2].text
    low = col[3].text
    close = col[4].text
    adj_close = col[5].text
    volume = col[6].text

    # Create a DataFrame for the current row
    row_df = pd.DataFrame({
        "Date": [date],
        "Open": [Open],
        "High": [high],
        "Low": [low],
        "Close": [close],
        "Adj Close": [adj_close],
        "Volume": [volume]
    })

    # Append the DataFrame to the list
    data_frames.append(row_df)

# Concatenate all the DataFrames in the list
tesla_data = pd.concat(data_frames, ignore_index=True)

# %%
tesla_data.tail()
# Out:
#             Date    Open    High     Low   Close Adj Close       Volume
# 95  May 08, 2023  173.72  173.80  169.19  171.79    171.79  112,249,400
# 96  May 05, 2023  163.97  170.79  163.51  170.06    170.06  107,440,900
# 97  May 04, 2023  162.71  162.95  159.65  161.20    161.20   95,108,500
# 98  May 03, 2023  160.01  165.00  159.91  160.61    160.61  119,728,000
# 99  May 02, 2023  161.88  165.49  158.93  160.31    160.31  128,259,700

# %%
gamestop = yf.Ticker("GME")
gamestop_data = tesla.history(period="max")

# %%
gamestop_data.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %%
with open('untitled2.html', 'r', encoding='utf-8') as file:
    # Read the HTML content
    html_content = file.read()

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Create an empty list to store DataFrames
data_frames = []

# Loop through table rows and extract data
for row in soup.find("tbody").find_all('tr'):
    col = row.find_all("td")
    date = col[0].text
    Open = col[1].text
    high = col[2].text
    low = col[3].text
    close = col[4].text
    adj_close = col[5].text
    volume = col[6].text

    # Create a DataFrame for the current row
    row_df = pd.DataFrame({
        "Date": [date],
        "Open": [Open],
        "High": [high],
        "Low": [low],
        "Close": [close],
        "Adj Close": [adj_close],
        "Volume": [volume]
    })

    # Append the DataFrame to the list
    data_frames.append(row_df)

# Concatenate all the DataFrames in the list
gamestop_data = pd.concat(data_frames, ignore_index=True)

# %%
gamestop_data.tail()
# Out:
#             Date   Open   High    Low  Close Adj Close     Volume
# 95  May 09, 2023  20.16  20.65  20.12  20.24     20.24  1,522,700
# 96  May 08, 2023  20.46  20.99  20.09  20.51     20.51  2,402,800
# 97  May 05, 2023  19.62  20.88  19.51  20.42     20.42  4,353,700
# 98  May 04, 2023  19.25  19.48  18.92  19.35     19.35  2,041,800
# 99  May 03, 2023  18.56  19.20  18.53  18.90     18.90  3,184,000

# %%
import matplotlib.pyplot as plt
last_10_rows = tesla_data.tail(10)

plt.plot(last_10_rows['Date'], last_10_rows['Close'])
plt.title('Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.show()
